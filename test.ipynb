# %%
import pandas as pd
import numpy as np

data = np.random.rand(100, 3)
df = pd.DataFrame(data, columns=["Column1", "Column2", "Column3"])

id = 2
start = (id-1)*10
end = start + 10
df = df.iloc[start:end, :] #filter df based on the job ID
df
# Out:
#      Column1   Column2   Column3
# 10  0.907897  0.345843  0.656505
# 11  0.161875  0.179706  0.693675
# 12  0.332242  0.981098  0.038614
# 13  0.491227  0.791363  0.515653
# 14  0.393022  0.513790  0.159381
# 15  0.376217  0.246385  0.912474
# 16  0.369096  0.842496  0.879769
# 17  0.985003  0.377695  0.664901
# 18  0.050615  0.261874  0.878011
# 19  0.578510  0.328436  0.146319
